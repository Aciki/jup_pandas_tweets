# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sb
from pylab import rcParams
import scipy
from scipy.stats.stats import pearsonr
from sklearn import preprocessing
from sklearn.preprocessing import scale
import nltk
from pandas import Series , DataFrame

# %%
adress = "/home/alek/Downloads/vaccination_tweets.csv"
df = pd.read_csv(filepath_or_buffer = adress , sep = ',', encoding='latin')
df.head()
# Out:
#                     id                user_name              user_location  \
# 0  1340539111971516416               Rachel Roh  La Crescenta-Montrose, CA
# 1  1338158543359250433              Albert Fong          San Francisco, CA
# 2  1337858199140118533  elið±ð¹ðªðºð                   Your Bed
# 3  1337855739918835717            Charles Adler     Vancouver, BC - Canada
# 4  1337854064604966912     Citizen News Channel                        NaN
#
#                                     user_description         user_created  \
# 0  Aggregator of Asian American news; scanning di...  2009-04-08 17:52:46
# 1  Marketing dude, tech geek, heavy metal & '80s ...  2009-09-21 15:27:30
# 2                                heil, hydra ðâº  2020-06-25 23:30:28
# 3  Hosting "CharlesAdlerTonight" Global News Radi...  2008-09-10 11:28:53
# 4  Citizen News Channel bringing you an alternati...  2020-04-23 17:58:42
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             405          1692             3247          False
# 1             834           666              178          False
# 2              10            88              155          False
# 3           49165          3933            21853           True
# 4             152           580             1473          False
#
#                   date                                               text  \
# 0  2020-12-20 06:06:44  Same folks said daikon paste could treat a cyt...
# 1  2020-12-13 16:27:13  While the world has been on the wrong side of ...
# 2  2020-12-12 20:33:45  #coronavirus #SputnikV #AstraZeneca #PfizerBio...
# 3  2020-12-12 20:23:59  Facts are immutable, Senator, even when you're...
# 4  2020-12-12 20:17:19  Explain to me again why we need a vaccine @Bor...
#
#                                             hashtags               source  \
# 0                                 ['PfizerBioNTech']  Twitter for Android
# 1                                                NaN      Twitter Web App
# 2  ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...  Twitter for Android
# 3                                                NaN      Twitter Web App
# 4     ['whereareallthesickpeople', 'PfizerBioNTech']   Twitter for iPhone
#
#    retweets  favorites  is_retweet
# 0         0          0       False
# 1         1          1       False
# 2         0          0       False
# 3       446       2129       False
# 4         0          0       False

# %%
print(" \nCount total NaN at each column in a DataFrame : \n\n", 
      df.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  id                    0
# user_name             0
# user_location       551
# user_description    131
# user_created          0
# user_followers        0
# user_friends          0
# user_favourites       0
# user_verified         0
# date                  0
# text                  0
# hashtags            673
# source                1
# retweets              0
# favorites             0
# is_retweet            0
# dtype: int64

# %%
df["user_location"].fillna("No user_location", inplace = True)
df["user_description"].fillna("No user_description", inplace = True)
df["source"].fillna("No source", inplace = True)

# %%
for row in df.loc[df.hashtags.isnull(), 'hashtags'].index:
    df.at[row, 'hashtags'] = ["'no_hashtags'"]

# %%
df.head(30)
# Out:
#                      id                             user_name  \
# 0   1340539111971516416                            Rachel Roh
# 1   1338158543359250433                           Albert Fong
# 2   1337858199140118533               elið±ð¹ðªðºð
# 3   1337855739918835717                         Charles Adler
# 4   1337854064604966912                  Citizen News Channel
# 5   1337852648389832708                                   Dee
# 6   1337851215875608579                     Gunther Fehlinger
# 7   1337850832256176136                   Dr.Krutika Kuppalli
# 8   1337850023531347969                           Erin Despas
# 9   1337842295857623042                          Ch.Amjad Ali
# 10  1337841934170255365                           Tamer Yazar
# 11  1337840331522453507                                VoiceM
# 12  1337815730486702087                                  WION
# 13  1337809196453081088                   Dr.Krutika Kuppalli
# 18  2020-12-12 15:27:42  .@Pfizer will rake in billions from its expens...
# 19  2020-12-12 15:10:09  The trump administration failed to deliver on ...
# 20  2020-12-12 15:00:17  How much did the #fda get paid to approve this...
# 21  2020-12-12 14:59:25  Anyone wondering why day after #PfizerBioNTech...
# 22  2020-12-12 14:59:02  Trump announces #vaccine rollout 'in less than...
# 23  2020-12-12 14:58:11  The US Food and Drug Administration (FDA) has ...
# 24  2020-12-12 14:46:27  Presenting you the top Medical News/Advancemen...
# 25  2020-12-12 14:43:45  No.1 of 2 done.\n\n#ThankYouNHS @NHSuk @MHRAgo...
# 26  2020-12-12 14:42:45  Wear a mask, wash your hands, and remain socia...
# 27  2020-12-12 14:41:19  â¦@AvgerinosMoscowâ© #PfizerBioNTech #FDA ap...
# 28  2020-12-12 14:26:28  Interesting and very detailed article showing ...
# 29  2020-12-12 14:11:09  ð #Vaccine #TrumpVaccine #AstraZeneca #Pfiz...
#
#                                              hashtags               source  \
# 0                                  ['PfizerBioNTech']  Twitter for Android
# 1                                     ['no_hashtags']      Twitter Web App
# 2   ['coronavirus', 'SputnikV', 'AstraZeneca', 'Pf...  Twitter for Android
# 3                                     ['no_hashtags']      Twitter Web App
# 4      ['whereareallthesickpeople', 'PfizerBioNTech']   Twitter for iPhone
# 5                                     ['no_hashtags']   Twitter for iPhone
# 6                                     ['vaccination']      Twitter Web App
# 7                     ['BidenHarris', 'Election2020']   Twitter for iPhone
# 8   ['CovidVaccine', 'covid19', 'PfizerBioNTech', ...      Twitter Web App
# 9   ['CovidVaccine', 'COVID19Vaccine', 'US', 'paku...      Twitter Web App
# 10                      ['PfizerBioNTech', 'Vaccine']      Twitter Web App
# 11  ['COVID19', 'CovidVaccine', 'vaccine', 'Corona...      Twitter Web App
# 12                                    ['no_hashtags']            TweetDeck
# 13                                 ['PfizerBioNTech']   Twitter for iPhone
# 14                                    ['no_hashtags']            TweetDeck
# 15                                        ['vaccine']   Twitter for iPhone
# 16  ['YellowFever', 'COVID19', 'ImmunityPassports'...      Twitter Web App
# 17          ['Iran', 'coronavirus', 'PfizerBioNTech']            TweetDeck
# 18                                   ['CovidVaccine']  Twitter for Android
# 19       ['COVIDIOTS', 'coronavirus', 'CovidVaccine']   Twitter for iPhone
# 20                                 ['fda', 'vaccine']      Twitter Web App
# 21                                 ['PfizerBioNTech']   Twitter for iPhone
# 22                                        ['vaccine']               Buffer
# 23                                    ['no_hashtags']      Twitter Web App
# 24                      ['docnosofficial', 'covid19']      Twitter Web App
# 25  ['ThankYouNHS', 'PfizerBioNTech', 'CovidVaccine']      Twitter Web App
# 26  ['stayhome', 'StayAtHome', 'StayAtHomeSaveLives']      Twitter Web App
# 27               ['PfizerBioNTech', 'FDA', 'vaccine']     Twitter for iPad
# 28                ['supplychain', 'sharedvisibility']     Twitter for iPad
# 29  ['Vaccine', 'TrumpVaccine', 'AstraZeneca', 'Pf...   Twitter for iPhone
#
#     retweets  favorites  is_retweet
# 0          0          0       False
# 1          1          1       False
# 2          0          0       False
# 3        446       2129       False
# 4          0          0       False
# 5          0          0       False
# 6          0          4       False
# 7          2         22       False
# 8          2          1       False
# 9          0          0       False
# 10         0          0       False
# 11         0          0       False
# 12         0         18       False
# 13        48         82       False
# 14         0          0       False
# 15         0          1       False
# 16         2          2       False
# 17         3          5       False
# 18         3          3       False
# 19         0          0       False
# 20         0          0       False
# 21         0          2       False
# 22         1          0       False
# 23         1          5       False
# 24         0          3       False
# 25         1         10       False
# 26         0          0       False
# 27         0          0       False
# 28         0          0       False
# 29         0          0       False

# %%
print(" \nCount total NaN at each column in a DataFrame : \n\n", 
      df.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  id                  0
# user_name           0
# user_location       0
# user_description    0
# user_created        0
# user_followers      0
# user_friends        0
# user_favourites     0
# user_verified       0
# date                0
# text                0
# hashtags            0
# source              0
# retweets            0
# favorites           0
# is_retweet          0
# dtype: int64

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/alek/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize
text = df['text'].to_string()
sent_tok = sent_tokenize(text)
print(sent_tok[:10])
# Out:
# ['0       Same folks said daikon paste could treat a cyt...\n1       While the world has been on the wrong side of ...\n2       #coronavirus #SputnikV #AstraZeneca #PfizerBio...\n3       Facts are immutable, Senator, even when you\'re...\n4       Explain to me again why we need a vaccine @Bor...\n5       Does anyone have any useful advice/guidance fo...\n6       it is a bit sad to claim the fame for success ...\n7       There have not been many bright days in 2020 b...\n8       Covid vaccine; You getting it?\\n\\n #CovidVacci...\n9       #CovidVaccine \\n\\nStates will start getting #C...\n10      while deaths are closing in on the 300,000 mar...\n11      @cnnbrk #COVID19 #CovidVaccine #vaccine #Coron...\n12      The agency also released new information for h...\n13      For all the women and healthcare providers who...\n14      "Expect 145 sites across all the states to rec...\n15      Trump announces #vaccine rollout \'in less than...\n16      UPDATED: #YellowFever &amp; #COVID19 #Immunity...\n17      Coronavirus: Iran reports 8,201 new cases, 221...\n18      .', "@Pfizer will rake in billions from its expens...\n19      The trump administration failed to deliver on ...\n20      How much did the #fda get paid to approve this...\n21      Anyone wondering why day after #PfizerBioNTech...\n22      Trump announces #vaccine rollout 'in less than...\n23      The US Food and Drug Administration (FDA) has ...\n24      Presenting you the top Medical News/Advancemen...\n25      No.1 of 2 done.\\n\\n#ThankYouNHS @NHSuk @MHRAgo...\n26      Wear a mask, wash your hands, and remain socia...\n27      â\x81¦@AvgerinosMoscowâ\x81© #PfizerBioNTech #FDA ap...\n28      Interesting and very detailed article showing ...\n29      ð\x9f\x92\x89 #Vaccine #TrumpVaccine #AstraZeneca #Pfiz...\n30      @ZubyMusic 6 deaths so far.", "\\nIt's only death,...\n31      @sbnumb3 @nytimes Please donâ\x80\x99t spread fake n...\n32      #ICYMI The #FDA Authorized the #PfizerBioNTech...\n33      All respect to due process but why not give ap...\n34      Vaccine!!", 'Anyone??', "#covid #Pfizervaccine #Pfiz...\n35      An immigrant Muslim couple find the COVID-19 V...\n36      The #FDA finally issues #EUA now comes the pro...\n37      Ladies and Gentlemen, now we have #CovidVaccin...\n38      FACT SHEET FOR HEALTHCARE PROVIDERS ADMINISTER...\n39      @mirekR9 @sputnikvaccine @AstraZeneca check ou...\n40      @mirekR9 @sputnikvaccine @AstraZeneca it's the...\n41      FACT SHEET FOR RECIPIENTS AND CAREGIVERS\\n\\n#P...\n42      #CovidVaccine #Pfizer-BioNTech COVID-19 #Pfize...\n43      Trump announces #vaccine rollout 'in less than...\n44      #FDA authorizes #PfizerBioNTech #coronavirus v...\n45      When The #CovidVaccine \\nPoisons Enough Of The...\n46      @realDonaldTrump Dairy dose of dumbsville by #...\n47      The US #FDA has approved two #coronavirus vacc...\n48      As @EMA_News gets set to approve #PfizerBioNTe...\n49      COVID-19: News and updates\\npublic questioned ...\n50      Tragedy.", 'Another life taken by corporate greed...\n51      Iâ\x80\x99ve never been so excited to get a vaccine ...\n52      Building on last weekâ\x80\x99s â\x80\x98trialâ\x80\x99 run and ...\n53      The first COVID-19 vaccine doses have arrived ...\n54      #Iran has told the World Health Organization i...\n55      Concerned about the side effects of the #Pfize...\n56      Such a great feeling.', 'A big thank you to all t...\n57      Members of the @teamsters delivered the first ...\n58      Getting my first dose of the #PfizerBioNTech #...\n59      Will you be taking the COVID-19 vaccine once a...\n60      @FarAndWide @erinotoole @MichelleRempel That R...\n61      #PfizerBioNTech New York state administered it...\n62      @CPHO_Canada #PfizerBioNTech = Female Steriliz...\n63      @CPHO_Canada Key #crushCovid milestone achieve...\n64      #INBOX | @GovParsonMO says shipments of the #P...\n65      @NYGovCuomo @CMargaronis @pfizer @UPS ??', "#Pfiz...\n66      ICU nurse Sandra ...

# %%
from nltk.tokenize import word_tokenize
text = df['text'].to_string()
word_tok = word_tokenize(text)
print(word_tok[:50])
# Out:
# ['0', 'Same', 'folks', 'said', 'daikon', 'paste', 'could', 'treat', 'a', 'cyt', '...', '1', 'While', 'the', 'world', 'has', 'been', 'on', 'the', 'wrong', 'side', 'of', '...', '2', '#', 'coronavirus', '#', 'SputnikV', '#', 'AstraZeneca', '#', 'PfizerBio', '...', '3', 'Facts', 'are', 'immutable', ',', 'Senator', ',', 'even', 'when', 'you', "'re", '...', '4', 'Explain', 'to', 'me', 'again']

# %%
word_tok = [w.lower() for w in word_tok]
# remove punctuation from each word
import string
table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in word_tok]
# remove remaining tokens that are not alphabetic
words = [word for word in stripped if word.isalpha()]
# filter out stop words
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
words = [w for w in words if not w in stop_words]
print(words[:50])
# Out:
# ['folks', 'said', 'daikon', 'paste', 'could', 'treat', 'cyt', 'world', 'wrong', 'side', 'coronavirus', 'sputnikv', 'astrazeneca', 'pfizerbio', 'facts', 'immutable', 'senator', 'even', 'explain', 'need', 'vaccine', 'bor', 'anyone', 'useful', 'adviceguidance', 'fo', 'bit', 'sad', 'claim', 'fame', 'success', 'many', 'bright', 'days', 'b', 'covid', 'vaccine', 'getting', 'nn', 'covidvacci', 'covidvaccine', 'nnstates', 'start', 'getting', 'c', 'deaths', 'closing', 'mar', 'cnnbrk', 'covidvaccine']

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize , word_tokenize
port_stem = PorterStemmer()

# %%
stemmed_words = []
for w in words:
    stemmed_words.append(port_stem.stem(w))
    
print(stemmed_words[:50])
# Out:
# ['folk', 'said', 'daikon', 'past', 'could', 'treat', 'cyt', 'world', 'wrong', 'side', 'coronaviru', 'sputnikv', 'astrazeneca', 'pfizerbio', 'fact', 'immut', 'senat', 'even', 'explain', 'need', 'vaccin', 'bor', 'anyon', 'use', 'adviceguid', 'fo', 'bit', 'sad', 'claim', 'fame', 'success', 'mani', 'bright', 'day', 'b', 'covid', 'vaccin', 'get', 'nn', 'covidvacci', 'covidvaccin', 'nnstate', 'start', 'get', 'c', 'death', 'close', 'mar', 'cnnbrk', 'covidvaccin']

# %%
from nltk.stem import WordNetLemmatizer
lem = WordNetLemmatizer()
from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()
lemm_words = []

for i in range(len(words)):
    lemm_words.append(lem.lemmatize(words[i]))
    
print(lemm_words[:50])
# Out:
# ['folk', 'said', 'daikon', 'paste', 'could', 'treat', 'cyt', 'world', 'wrong', 'side', 'coronavirus', 'sputnikv', 'astrazeneca', 'pfizerbio', 'fact', 'immutable', 'senator', 'even', 'explain', 'need', 'vaccine', 'bor', 'anyone', 'useful', 'adviceguidance', 'fo', 'bit', 'sad', 'claim', 'fame', 'success', 'many', 'bright', 'day', 'b', 'covid', 'vaccine', 'getting', 'nn', 'covidvacci', 'covidvaccine', 'nnstates', 'start', 'getting', 'c', 'death', 'closing', 'mar', 'cnnbrk', 'covidvaccine']

# %%
from nltk import pos_tag
pos_tagaed_words = pos_tag(words)
print(pos_tagaed_words[:20])
# Out:
# [('folks', 'NNS'), ('said', 'VBD'), ('daikon', 'JJ'), ('paste', 'NN'), ('could', 'MD'), ('treat', 'VB'), ('cyt', 'JJ'), ('world', 'NN'), ('wrong', 'JJ'), ('side', 'NN'), ('coronavirus', 'NN'), ('sputnikv', 'NN'), ('astrazeneca', 'NN'), ('pfizerbio', 'NN'), ('facts', 'VBZ'), ('immutable', 'JJ'), ('senator', 'NN'), ('even', 'RB'), ('explain', 'VBP'), ('need', 'VBP')]

# %%
from nltk.probability import FreqDist
fd = FreqDist(words)

# %%
import matplotlib.pyplot as plt
fd.plot(20,cumulative = False)
plt.show()

# %%
x = df[['user_followers','user_friends','user_favourites','retweets']]

# %%
corr = x.corr()
corr
# Out:
#                  user_followers  user_friends  user_favourites  retweets
# user_followers         1.000000     -0.031534        -0.034246  0.059080
# user_friends          -0.031534      1.000000         0.217072  0.032259
# user_favourites       -0.034246      0.217072         1.000000  0.010738
# retweets               0.059080      0.032259         0.010738  1.000000

# %%
rcParams['figure.figsize'] = (10, 6)
sb.set_style('whitegrid')

# %%
retweets = df['retweets']
user_followers = df['user_followers']

# %%
user_followers_matrix=user_followers.values.reshape(-1,1)
scaled = preprocessing.MinMaxScaler(feature_range=(0,100))
scaled_user_followers = scaled.fit_transform(user_followers_matrix)
plt.plot(scaled_user_followers)
plt.show()

# %%
retweets_matrix = retweets.values.reshape(-1,1)
scaled = preprocessing.MinMaxScaler(feature_range=(0,100))
scaled_retweets = scaled.fit_transform(retweets_matrix)
plt.plot(scaled_retweets)
plt.show()

# %%
sb.boxplot(x = 'retweets' ,  y = 'user_followers' , data = df , palette = 'hls')
#df[(np.abs(stats.zscore(df['retweets'])) < 3)]
# Out:
# <AxesSubplot:xlabel='retweets', ylabel='user_followers'>

# %%
! pip3 install Plotly
! pip3 install cufflinks
# Out:
# Requirement already satisfied: Plotly in ./.local/lib/python3.8/site-packages (4.14.3)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from Plotly) (1.14.0)
# Requirement already satisfied: retrying>=1.3.3 in ./.local/lib/python3.8/site-packages (from Plotly) (1.3.3)
# Requirement already satisfied: cufflinks in ./.local/lib/python3.8/site-packages (0.17.3)
# Requirement already satisfied: plotly>=4.1.1 in ./.local/lib/python3.8/site-packages (from cufflinks) (4.14.3)
# Requirement already satisfied: colorlover>=0.2.1 in ./.local/lib/python3.8/site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in ./.local/lib/python3.8/site-packages (from cufflinks) (7.6.3)
# Requirement already satisfied: pandas>=0.19.2 in ./.local/lib/python3.8/site-packages (from cufflinks) (1.1.4)
# Requirement already satisfied: numpy>=1.9.2 in ./.local/lib/python3.8/site-packages (from cufflinks) (1.19.4)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from cufflinks) (1.14.0)
# Requirement already satisfied: ipython>=5.3.0 in /usr/lib/python3/dist-packages (from cufflinks) (7.13.0)
# Requirement already satisfied: setuptools>=34.4.1 in /usr/lib/python3/dist-packages (from cufflinks) (45.2.0)
# Requirement already satisfied: retrying>=1.3.3 in ./.local/lib/python3.8/site-packages (from plotly>=4.1.1->cufflinks) (1.3.3)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/lib/python3/dist-packages (from ipywidgets>=7.0.0->cufflinks) (4.3.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in ./.local/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cufflinks) (1.0.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/lib/python3/dist-packages (from ipywidgets>=7.0.0->cufflinks) (5.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in ./.local/lib/python3.8/site-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/lib/python3/dist-packages (from ipywidgets>=7.0.0->cufflinks) (5.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/lib/python3/dist-packages (from pandas>=0.19.2->cufflinks) (2.7.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/lib/python3/dist-packages (from pandas>=0.19.2->cufflinks) (2019.3)
# Requirement already satisfied: pexpect in /usr/lib/python3/dist-packages (from ipython>=5.3.0->cufflinks) (4.6.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/lib/python3/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.0.3)

# %%
! pip3 install chart_studio
# Out:
# Requirement already satisfied: chart_studio in ./.local/lib/python3.8/site-packages (1.1.0)
# Requirement already satisfied: plotly in ./.local/lib/python3.8/site-packages (from chart_studio) (4.14.3)
# Requirement already satisfied: retrying>=1.3.3 in ./.local/lib/python3.8/site-packages (from chart_studio) (1.3.3)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from chart_studio) (2.22.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from chart_studio) (1.14.0)

# %%
import chart_studio.plotly as py
import cufflinks as cf
import plotly.tools as tls
import plotly.graph_objs as go
import chart_studio

# %%
chart_studio.tools.set_credentials_file(username='aciki', api_key='####')

# %%
from sklearn.preprocessing import StandardScaler
subset = df[['retweets','user_followers']]
df_data_std = StandardScaler().fit_transform(subset)
data_tweets = pd.DataFrame(df_data_std)
data_tweets.columns=['retweets','user_followers']

# %%
data_tweets.iplot(filename = 'data_retweets_uF')
# Out:
#         <iframe
#             width="100%"
#             height="525px"
#             src="https://plotly.com/~Aciki/1.embed"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
